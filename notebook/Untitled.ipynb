# %% [markdown]
# # Limpieza de base de datos tipo texto estado: caótico

# %% [markdown]
# Ejemplo de **limpieza avanzada de datos desordenados**
# provenientes de un archivo de Excel.
# El archivo contiene información mezclada en una sola columna sobre:
# - Nombres y apellidos
# - Roles
# - Ciudades
# - Correos electrónicos
# - Texto sucio y símbolos extra

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Transformar el archivo “corrupto” en una tabla limpia y estructurada, en tipo de archivo excel.

# %% [markdown]
# ## Acciones

# %% [markdown]
# # Carga de archivo y exploración inicial

# %% [markdown]
# - carga de librerías
# - visualización
# - estructura y tipos de dato

# %%
# importar librerías
import pandas as pd
import numpy as np
import re

# %%
# carga de datos 

file_path = r"C:\Users\andre\OneDrive\Data_Cleaning_Portfolio\Datos_tipo_texto\datos_originales\corrupted_csv_example.xlsx"
df_raw = pd.read_excel(file_path)
df = df_raw.copy()
df_raw.head()
# Out:
#                                        Corrupted_Row
# 0  Paola López::Support Agent::Manta::paola0@g ma...
# 1  Brian Ramirez::Developer::Manta::brian1@g mail...
# 2  Eduardo Bravo;Product Owner;Daule;eduardo2@g m...
# 3    \tMarioSánchez\tQALead\tManta\tmario3@gmail.com
# 4  Cecilia---Torres|Developer|Tena|cecilia4@g---m...

# %%
# exploracion del set de datos 
print("Shape del dataframe:", df.shape)
print("Columnas:", df.columns.tolist())

# Mostrar algunas filas de ejemplo
pd.set_option("display.max_colwidth", 200)
df.sample(10, random_state=42)
# Out:
# Shape del dataframe: (50, 1)
# Columnas: ['Corrupted_Row']
#                                                                   Corrupted_Row
# 13                        Hector Jaramillo|IT Lead|Ambato|hector13@g mail . com
# 39                               Javier Moreno,HR,Milagro,javier39@g mail . com
# 30                        Roberto Casas\tQA Lead\tManta\troberto30@g mail . com
# 45  Claudia Pérez::Developer::Riobamba::claudia45@g mail . com:: note:fix-this
# 17              Javier MorenoQA LeadMachalajavier17@g mail . com note:fix-this
# 48                     Marcelo Paredes   Sales   Manta   marcelo48@g mail . com
# 26      Melissa  Viteri      Marketing      Tena      melissa26@g  mail  .  com
# 25                 Juan Ruiz;IT Lead;Cuenca;juan25@g mail . com; note:fix-this
# 32                 Claudia---Pérez|Developer|Manta|claudia32@g---mail---.---com
# 19              Andrea Molina,Sales,Daule,andrea19@g mail . com, note:fix-this

# %% [markdown]
# # Extracción y normalización de correo electrónico

# %% [markdown]
# - normalización de variantes de gmail
# - Extraer correo a nueva columna
# - Eliminar texto residual
# - Se crea una columna sin el email

# %%
#función que reemplaza variantes de gmail
def normalize_gmail(text: str) -> str:
    
    if not isinstance(text, str):
        text = str(text)
    # Patrón para g[algo]mail[algo].com con espacios, guiones o underscores
    pattern = re.compile(r'g[\s\-_]*mail[\s\-_]*[\.\-_\s]*com', re.IGNORECASE)
    return pattern.sub('gmail.com', text)

# extrae y devuelve el correo limpio 
def extract_email_and_rest(text: str):
    
    if not isinstance(text, str):
        text = str(text)
    t = normalize_gmail(text)

    # Buscar 'usuario@gmail.com'
    m = re.search(r'([\w\.]+@gmail\.com)', t)
    email = m.group(1) if m else None

    if email:
        rest = t.replace(email, " ")
    else:
        rest = t

    # Quitar la marca de texto basura
    rest = re.sub(r'\bnote:fix-this\b', " ", rest, flags=re.IGNORECASE)

    # Limpiar espacios extra
    rest = re.sub(r'\s+', " ", rest).strip()

    return email, rest


# Aplicar la función a cada fila
df["email"], df["text_without_email"] = zip(*df["Corrupted_Row"].map(extract_email_and_rest))


df[["Corrupted_Row", "email", "text_without_email"]].head(10)
# Out:
#                                                                  Corrupted_Row  \
# 0                       Paola López::Support Agent::Manta::paola0@g mail . com
# 1                         Brian Ramirez::Developer::Manta::brian1@g mail . com
# 2                      Eduardo Bravo;Product Owner;Daule;eduardo2@g mail . com
# 3                              \tMarioSánchez\tQALead\tManta\tmario3@gmail.com
# 4  Cecilia---Torres|Developer|Tena|cecilia4@g---mail---.---com| note:fix-this
# 5                  Juan Carlos MenaSalesDaulejuan5@g mail . com note:fix-this
# 6                    Patricia---Jaramillo,HR,Puyo,patricia6@g---mail---.---com
# 7                          Rafael Paredes   HR   Cuenca   rafael7@g mail . com
# 8                  Hector Jaramillo   Manager   Machala   hector8@g mail . com
# 9                        Veronica Lasso;Developer;Daule;veronica9@g mail . com
#
#                            email                   text_without_email
# 0               paola0@gmail.com  Paola López::Support Agent::Manta::
# 1               brian1@gmail.com    Brian Ramirez::Developer::Manta::
# 2             eduardo2@gmail.com   Eduardo Bravo;Product Owner;Daule;
# 3               mario3@gmail.com            MarioSánchez QALead Manta
# 4             cecilia4@gmail.com   Cecilia---Torres|Developer|Tena| |
# 5  MenaSalesDaulejuan5@gmail.com                          Juan Carlos
# 6            patricia6@gmail.com        Patricia---Jaramillo,HR,Puyo,
# 7              rafael7@gmail.com             Rafael Paredes HR Cuenca
# 8              hector8@gmail.com     Hector Jaramillo Manager Machala
# 9            veronica9@gmail.com      Veronica Lasso;Developer;Daule;

# %% [markdown]
# ## Limpieza básica de texto

# %% [markdown]
# - Reemplazar tabuladores, comas, barras y guiones
# - Eliminar caracteres repetidos
# - Reemplazar guiones bajos por espacios
# - Normalizar espacios múltiples
# - Crear columna nueva de texto limpio

# %%
# Separación de texto 
def split_name_role_city(text: str):
    
    if not isinstance(text, str):
        text = "" if pd.isna(text) else str(text)

    t = text.strip()
    if not t:
        return pd.Series([None, None, None])

    
    # 1. Normalización de separadores
    t = t.replace("\t", "|")   # tab
    t = t.replace("---", " ")  # guiones largos pegados
    t = t.replace("_", " ")    # underscores
    
    # Unificar varios separadores a '|'
    for sep in ["::", ";", "|", ","]:
        t = t.replace(sep, "|")

    # Limpiar espacios múltiples
    t = re.sub(r"\s+", " ", t).strip()

    
    # 2. División por separador '|'
    parts = [p.strip() for p in t.split("|") if p.strip()]

    # Caso ideal: 3 partes
    if len(parts) >= 3:
        return pd.Series([parts[0], parts[1], parts[2]])

    # Si hay 1 sola parte, intentar separar por bloques de espacios
    if len(parts) == 1:
        subparts = [p.strip() for p in re.split(r"\s{2,}", parts[0]) if p.strip()]
        if len(subparts) >= 3:
            return pd.Series(subparts[:3])
        elif len(subparts) == 2:
            return pd.Series([subparts[0], subparts[1], None])
        else:
            return pd.Series([parts[0], None, None])

    # Si hay 2 partes → name y role/city
    if len(parts) == 2:
        return pd.Series([parts[0], parts[1], None])

    # Incompleto
    return pd.Series([None, None, None])


# Aplicar al dataframe
df[["name", "role", "city"]] = df["text_without_email"].apply(split_name_role_city)

# Mostrar avances
df[["Corrupted_Row", "name", "role", "city", "email"]].head(12)
# Out:
#                                                                   Corrupted_Row  \
# 0                        Paola López::Support Agent::Manta::paola0@g mail . com
# 1                          Brian Ramirez::Developer::Manta::brian1@g mail . com
# 2                       Eduardo Bravo;Product Owner;Daule;eduardo2@g mail . com
# 3                               \tMarioSánchez\tQALead\tManta\tmario3@gmail.com
# 4   Cecilia---Torres|Developer|Tena|cecilia4@g---mail---.---com| note:fix-this
# 5                   Juan Carlos MenaSalesDaulejuan5@g mail . com note:fix-this
# 6                     Patricia---Jaramillo,HR,Puyo,patricia6@g---mail---.---com
# 7                           Rafael Paredes   HR   Cuenca   rafael7@g mail . com
# 8                   Hector Jaramillo   Manager   Machala   hector8@g mail . com
# 9                         Veronica Lasso;Developer;Daule;veronica9@g mail . com
# 10                      Marco Vinueza   IT Lead   Ambato   marco10@g mail . com
# 11                            Sergio Paz::QA Lead::Manta::sergio11@g mail . com
#
#                                 name           role   city  \
# 0                        Paola López  Support Agent  Manta
# 1                      Brian Ramirez      Developer  Manta
# 2                      Eduardo Bravo  Product Owner  Daule
# 3          MarioSánchez QALead Manta           None   None
# 4                     Cecilia Torres      Developer   Tena
# 5                        Juan Carlos           None   None
# 6                 Patricia Jaramillo             HR   Puyo
# 7           Rafael Paredes HR Cuenca           None   None
# 8   Hector Jaramillo Manager Machala           None   None
# 9                     Veronica Lasso      Developer  Daule
# 10      Marco Vinueza IT Lead Ambato           None   None
# 11                        Sergio Paz        QA Lead  Manta
#
#                             email
# 0                paola0@gmail.com
# 1                brian1@gmail.com
# 2              eduardo2@gmail.com
# 3                mario3@gmail.com
# 4              cecilia4@gmail.com
# 5   MenaSalesDaulejuan5@gmail.com
# 6             patricia6@gmail.com
# 7               rafael7@gmail.com
# 8               hector8@gmail.com
# 9             veronica9@gmail.com
# 10              marco10@gmail.com
# 11             sergio11@gmail.com

# %%
pd.set_option('display.max_rows', None)       # Muestra todas las filas
pd.set_option('display.max_columns', None)    # Muestra todas las columnas
pd.set_option('display.max_colwidth', None)   # No corta el texto dentro de las celdas

df
# Out:
#                                                                   Corrupted_Row  \
# 0                        Paola López::Support Agent::Manta::paola0@g mail . com
# 1                          Brian Ramirez::Developer::Manta::brian1@g mail . com
# 2                       Eduardo Bravo;Product Owner;Daule;eduardo2@g mail . com
# 3                               \tMarioSánchez\tQALead\tManta\tmario3@gmail.com
# 4   Cecilia---Torres|Developer|Tena|cecilia4@g---mail---.---com| note:fix-this
# 5                   Juan Carlos MenaSalesDaulejuan5@g mail . com note:fix-this
# 6                     Patricia---Jaramillo,HR,Puyo,patricia6@g---mail---.---com
# 7                           Rafael Paredes   HR   Cuenca   rafael7@g mail . com
# 8                   Hector Jaramillo   Manager   Machala   hector8@g mail . com
# 9                         Veronica Lasso;Developer;Daule;veronica9@g mail . com
# 10                      Marco Vinueza   IT Lead   Ambato   marco10@g mail . com
# 11                            Sergio Paz::QA Lead::Manta::sergio11@g mail . com
# 12                     Luis Gomez   Support Agent   Daule   luis12@g mail . com
# 13                        Hector Jaramillo|IT Lead|Ambato|hector13@g mail . com
# 14                       Luciana  Aguirre;Sales;Daule;luciana14@g  mail  .  com
# 15                Cecilia_Torres\tProduct_Owner\tAmbato\tcecilia15@g_mail_._com
# 16                             Gina Córdova::QA Lead::Puyo::gina16@g mail . com
# 17              Javier MorenoQA LeadMachalajavier17@g mail . com note:fix-this
# 18                          Elena Rivas::Manager::Milagro::elena18@g mail . com
# 19              Andrea Molina,Sales,Daule,andrea19@g mail . com, note:fix-this
# 20                            Hector Jaramillo;Sales;Tena;hector20@g mail . com
# 21                          Monica Silva\tQA Lead\tQuito\tmonica21@g mail . com
# 22               Maria Fernandez   Support Agent   Quito   maria22@g mail . com
# 23                            Pablo Villacis|Manager|Quito|pablo23@g mail . com
# 24  EduardoBravo\tProductOwner\tLatacunga\teduardo24@gmail.com\t note:fix-this
# 25                 Juan Ruiz;IT Lead;Cuenca;juan25@g mail . com; note:fix-this
# 26      Melissa  Viteri      Marketing      Tena      melissa26@g  mail  .  com
# 27                      Veronica Lasso,IT Lead,Riobamba,veronica27@g mail . com
# 28              Monica Silva   Finance Director   Manta   monica28@g mail . com
# 29                     Luciana Aguirre\tManager\tAmbato\tluciana29@g mail . com
# 30                        Roberto Casas\tQA Lead\tManta\troberto30@g mail . com
# 31                       Roberto Casas\tSales\tRiobamba\troberto31@g mail . com
# 32                 Claudia---Pérez|Developer|Manta|claudia32@g---mail---.---com
# 33                Ramiro Andrade\tSupport Agent\tMilagro\tramiro33@g mail . com
# 34                             Tania Suarez;QA Lead;Ambato;tania34@g mail . com
# 35                  Eduardo Bravo::Support Agent::Quito::eduardo35@g mail . com
# 36      Carlos---Rojas::HR::Quito::carlos36@g---mail---.---com:: note:fix-this
# 37                         Gina Córdova;Product Owner;Daule;gina37@g mail . com
# 38              Juan Carlos Mena,Finance Director,Latacunga,juan38@g mail . com
# 39                               Javier Moreno,HR,Milagro,javier39@g mail . com
# 40                                  RamiroAndrade::HR::Loja::ramiro40@gmail.com
# 41                  Gina Córdova::Product Owner::Guayaquil::gina41@g mail . com
# 42         Paola López\tSales\tGuayaquil\tpaola42@g mail . com\t note:fix-this
# 43                               Luis GomezSupport AgentTenaluis43@g mail . com
# 44             Pablo Villacis,QA Lead,Puyo,pablo44@g mail . com, note:fix-this
# 45  Claudia Pérez::Developer::Riobamba::claudia45@g mail . com:: note:fix-this
# 46                            MonicaSilva::Sales::Guayaquil::monica46@gmail.com
# 47        Diego Torres::QA Lead::Milagro::diego47@g mail . com:: note:fix-this
# 48                     Marcelo Paredes   Sales   Manta   marcelo48@g mail . com
# 49                        Veronica Lasso|Manager|Ambato|veronica49@g mail . com
#
#                             email  \
# 0                paola0@gmail.com
# 1                brian1@gmail.com
# 2              eduardo2@gmail.com
# 3                mario3@gmail.com
# 4              cecilia4@gmail.com
# 5   MenaSalesDaulejuan5@gmail.com
# 6             patricia6@gmail.com
# 7               rafael7@gmail.com
# 8               hector8@gmail.com
# 9             veronica9@gmail.com
# 10              marco10@gmail.com
# 11             sergio11@gmail.com
# 12               luis12@gmail.com
# 13             hector13@gmail.com
# 14            luciana14@gmail.com
# 15            cecilia15@gmail.com
# 16               gina16@gmail.com
# 17  LeadMachalajavier17@gmail.com
# 18              elena18@gmail.com
# 19             andrea19@gmail.com
# 20             hector20@gmail.com
# 21             monica21@gmail.com
# 22              maria22@gmail.com
# 23              pablo23@gmail.com
# 24            eduardo24@gmail.com
# 25               juan25@gmail.com
# 26            melissa26@gmail.com
# 27           veronica27@gmail.com
# 28             monica28@gmail.com
# 29            luciana29@gmail.com
# 30            roberto30@gmail.com
# 31            roberto31@gmail.com
# 32            claudia32@gmail.com
# 33             ramiro33@gmail.com
# 34              tania34@gmail.com
# 35            eduardo35@gmail.com
# 36             carlos36@gmail.com
# 37               gina37@gmail.com
# 38               juan38@gmail.com
# 39             javier39@gmail.com
# 40             ramiro40@gmail.com
# 41               gina41@gmail.com
# 42              paola42@gmail.com
# 43      AgentTenaluis43@gmail.com
# 44              pablo44@gmail.com
# 45            claudia45@gmail.com
# 46             monica46@gmail.com
# 47              diego47@gmail.com
# 48            marcelo48@gmail.com
# 49           veronica49@gmail.com
#
#                               text_without_email  \
# 0            Paola López::Support Agent::Manta::
# 1              Brian Ramirez::Developer::Manta::
# 2             Eduardo Bravo;Product Owner;Daule;
# 3                      MarioSánchez QALead Manta
# 4             Cecilia---Torres|Developer|Tena| |
# 5                                    Juan Carlos
# 6                  Patricia---Jaramillo,HR,Puyo,
# 7                       Rafael Paredes HR Cuenca
# 8               Hector Jaramillo Manager Machala
# 9                Veronica Lasso;Developer;Daule;
# 10                  Marco Vinueza IT Lead Ambato
# 11                  Sergio Paz::QA Lead::Manta::
# 12                Luis Gomez Support Agent Daule
# 13              Hector Jaramillo|IT Lead|Ambato|
# 14                  Luciana Aguirre;Sales;Daule;
# 15           Cecilia_Torres Product_Owner Ambato
# 16                 Gina Córdova::QA Lead::Puyo::
# 17                               Javier MorenoQA
# 18               Elena Rivas::Manager::Milagro::
# 19                  Andrea Molina,Sales,Daule, ,
# 20                  Hector Jaramillo;Sales;Tena;
# 21                    Monica Silva QA Lead Quito
# 22           Maria Fernandez Support Agent Quito
# 23                 Pablo Villacis|Manager|Quito|
# 24           EduardoBravo ProductOwner Latacunga
# 25                   Juan Ruiz;IT Lead;Cuenca; ;
# 26                 Melissa Viteri Marketing Tena
# 27              Veronica Lasso,IT Lead,Riobamba,
# 28           Monica Silva Finance Director Manta
# 29                Luciana Aguirre Manager Ambato
# 30                   Roberto Casas QA Lead Manta
# 31                  Roberto Casas Sales Riobamba
# 32              Claudia---Pérez|Developer|Manta|
# 33          Ramiro Andrade Support Agent Milagro
# 34                  Tania Suarez;QA Lead;Ambato;
# 35         Eduardo Bravo::Support Agent::Quito::
# 36                Carlos---Rojas::HR::Quito:: ::
# 37             Gina Córdova;Product Owner;Daule;
# 38  Juan Carlos Mena,Finance Director,Latacunga,
# 39                     Javier Moreno,HR,Milagro,
# 40                     RamiroAndrade::HR::Loja::
# 41      Gina Córdova::Product Owner::Guayaquil::
# 42                   Paola López Sales Guayaquil
# 43                             Luis GomezSupport
# 44                Pablo Villacis,QA Lead,Puyo, ,
# 45       Claudia Pérez::Developer::Riobamba:: ::
# 46               MonicaSilva::Sales::Guayaquil::
# 47           Diego Torres::QA Lead::Milagro:: ::
# 48                   Marcelo Paredes Sales Manta
# 49                Veronica Lasso|Manager|Ambato|
#
#                                     name              role       city
# 0                            Paola López     Support Agent      Manta
# 1                          Brian Ramirez         Developer      Manta
# 2                          Eduardo Bravo     Product Owner      Daule
# 3              MarioSánchez QALead Manta              None       None
# 4                         Cecilia Torres         Developer       Tena
# 5                            Juan Carlos              None       None
# 6                     Patricia Jaramillo                HR       Puyo
# 7               Rafael Paredes HR Cuenca              None       None
# 8       Hector Jaramillo Manager Machala              None       None
# 9                         Veronica Lasso         Developer      Daule
# 10          Marco Vinueza IT Lead Ambato              None       None
# 11                            Sergio Paz           QA Lead      Manta
# 12        Luis Gomez Support Agent Daule              None       None
# 13                      Hector Jaramillo           IT Lead     Ambato
# 14                       Luciana Aguirre             Sales      Daule
# 15   Cecilia Torres Product Owner Ambato              None       None
# 16                          Gina Córdova           QA Lead       Puyo
# 17                       Javier MorenoQA              None       None
# 18                           Elena Rivas           Manager    Milagro
# 19                         Andrea Molina             Sales      Daule
# 20                      Hector Jaramillo             Sales       Tena
# 21            Monica Silva QA Lead Quito              None       None
# 22   Maria Fernandez Support Agent Quito              None       None
# 23                        Pablo Villacis           Manager      Quito
# 24   EduardoBravo ProductOwner Latacunga              None       None
# 25                             Juan Ruiz           IT Lead     Cuenca
# 26         Melissa Viteri Marketing Tena              None       None
# 27                        Veronica Lasso           IT Lead   Riobamba
# 28   Monica Silva Finance Director Manta              None       None
# 29        Luciana Aguirre Manager Ambato              None       None
# 30           Roberto Casas QA Lead Manta              None       None
# 31          Roberto Casas Sales Riobamba              None       None
# 32                         Claudia Pérez         Developer      Manta
# 33  Ramiro Andrade Support Agent Milagro              None       None
# 34                          Tania Suarez           QA Lead     Ambato
# 35                         Eduardo Bravo     Support Agent      Quito
# 36                          Carlos Rojas                HR      Quito
# 37                          Gina Córdova     Product Owner      Daule
# 38                      Juan Carlos Mena  Finance Director  Latacunga
# 39                         Javier Moreno                HR    Milagro
# 40                         RamiroAndrade                HR       Loja
# 41                          Gina Córdova     Product Owner  Guayaquil
# 42           Paola López Sales Guayaquil              None       None
# 43                     Luis GomezSupport              None       None
# 44                        Pablo Villacis           QA Lead       Puyo
# 45                         Claudia Pérez         Developer   Riobamba
# 46                           MonicaSilva             Sales  Guayaquil
# 47                          Diego Torres           QA Lead    Milagro
# 48           Marcelo Paredes Sales Manta              None       None
# 49                        Veronica Lasso           Manager     Ambato

# %%
# texto uniforme 
def normalize_basic(text):
    
    if not isinstance(text, str):
        text = str(text)

    t = text.replace("\t", " ")
    t = t.replace("|", " ")
    t = t.replace(";", " ")
    t = t.replace(",", " ")   
    t = t.replace("::", " ")
    t = t.replace("___", " ")
    t = t.replace("---", " ")
    t = t.replace("_", " ")  

    t = re.sub(r"\s+", " ", t).strip()
    return t

df["clean_text"] = df["text_without_email"].apply(normalize_basic)

# %% [markdown]
# ## LISTAS Y FUNCIONES DE SEPARACIÓN ROL, NOMBRE Y CIUDAD

# %% [markdown]
# - Lista de ciudades detectadas en el archivo
# - Lista de roles y palabras clave
# - Diccionario para estandarizar variaciones de roles
# - Generar columnas para cada item requerido

# %%
# Lista de ciudades conocidas
CITIES = [
    "Ambato", "Cuenca", "Daule", "Guayaquil", "Latacunga", "Loja",
    "Manta", "Milagro", "Puyo", "Quito", "Riobamba", "Tena", "Machala"
]

# Keywords de roles
ROLE_KEYWORDS = [
    "Developer",
    "Finance",
    "Director",
    "HR",
    "IT",
    "Lead",
    "Manager",
    "Product",
    "Owner",
    "QA",
    "Sales",
    "Support",
    "Agent",
    "Marketing"
]

ROLE_NORMALIZATION = {
    "ProductOwner": "Product Owner",
    "Product_Owner": "Product Owner",
    "QALead": "QA Lead"
}
def smart_split_camel(text):
    """
    Separa palabras pegadas basándose en CamelCase:
    Ej: 'MenaSalesDaule' → 'Mena Sales Daule'
    """
    return re.sub(r'(?<=[a-záéíóúñ])(?=[A-ZÁÉÍÓÚÑ])', ' ', text)

def advanced_split(text: str):
    if not isinstance(text, str):
        return pd.Series([None, None, None])

    # separar camelCase (MarioSánchez, MenaSalesDaule, etc.)
    t = smart_split_camel(text)
    # limpiar espacios extra
    t = re.sub(r"\s+", " ", t).strip()
    words = t.split()

    name_parts = []
    role_parts = []
    city = None

    for w in words:
        # normalizar variantes raras primero
        w_norm = ROLE_NORMALIZATION.get(w, w)

        # 1) CIUDADES
        if w_norm.capitalize() in CITIES:
            city = w_norm.capitalize()
            continue

        # 2) ROLES (por palabras clave)
        if w_norm in ROLE_KEYWORDS:
            role_parts.append(w_norm)
            continue

        # 3) SI NO ES NI CIUDAD NI ROL → NOMBRE
        name_parts.append(w_norm)

    name = " ".join(name_parts) if name_parts else None
    role = " ".join(role_parts) if role_parts else None

    return pd.Series([name, role, city])

# %%
df[["name", "role", "city"]] = df["clean_text"].apply(advanced_split)

df[["clean_text", "name", "role", "city", "email"]].head(20)
# Out:
#                              clean_text                   name           role  \
# 0       Paola López Support Agent Manta            Paola López  Support Agent
# 1         Brian Ramirez Developer Manta          Brian Ramirez      Developer
# 2     Eduardo Bravo Product Owner Daule          Eduardo Bravo  Product Owner
# 3             MarioSánchez QALead Manta  Mario Sánchez QA Lead           None
# 4         Cecilia Torres Developer Tena         Cecilia Torres      Developer
# 5                           Juan Carlos            Juan Carlos           None
# 6            Patricia Jaramillo HR Puyo     Patricia Jaramillo             HR
# 7              Rafael Paredes HR Cuenca         Rafael Paredes             HR
# 8      Hector Jaramillo Manager Machala       Hector Jaramillo        Manager
# 9        Veronica Lasso Developer Daule         Veronica Lasso      Developer
# 10         Marco Vinueza IT Lead Ambato          Marco Vinueza        IT Lead
# 11             Sergio Paz QA Lead Manta             Sergio Paz        QA Lead
# 12       Luis Gomez Support Agent Daule             Luis Gomez  Support Agent
# 13      Hector Jaramillo IT Lead Ambato       Hector Jaramillo        IT Lead
# 14          Luciana Aguirre Sales Daule        Luciana Aguirre          Sales
# 15  Cecilia Torres Product Owner Ambato         Cecilia Torres  Product Owner
# 16            Gina Córdova QA Lead Puyo           Gina Córdova        QA Lead
# 17                      Javier MorenoQA          Javier Moreno             QA
# 18          Elena Rivas Manager Milagro            Elena Rivas        Manager
# 19            Andrea Molina Sales Daule          Andrea Molina          Sales
#
#        city                          email
# 0     Manta               paola0@gmail.com
# 1     Manta               brian1@gmail.com
# 2     Daule             eduardo2@gmail.com
# 3     Manta               mario3@gmail.com
# 4      Tena             cecilia4@gmail.com
# 5      None  MenaSalesDaulejuan5@gmail.com
# 6      Puyo            patricia6@gmail.com
# 7    Cuenca              rafael7@gmail.com
# 8   Machala              hector8@gmail.com
# 9     Daule            veronica9@gmail.com
# 10   Ambato              marco10@gmail.com
# 11    Manta             sergio11@gmail.com
# 12    Daule               luis12@gmail.com
# 13   Ambato             hector13@gmail.com
# 14    Daule            luciana14@gmail.com
# 15   Ambato            cecilia15@gmail.com
# 16     Puyo               gina16@gmail.com
# 17     None  LeadMachalajavier17@gmail.com
# 18  Milagro              elena18@gmail.com
# 19    Daule             andrea19@gmail.com

# %% [markdown]
# ## Exploración de archivo

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 500)

df_problem = df[df[["name", "role", "city"]].isna().any(axis=1)]
df_problem
# Out:
#                                                       Corrupted_Row                          email         text_without_email                   name     role   city                 clean_text
# 3                   \tMarioSánchez\tQALead\tManta\tmario3@gmail.com               mario3@gmail.com  MarioSánchez QALead Manta  Mario Sánchez QA Lead     None  Manta  MarioSánchez QALead Manta
# 5       Juan Carlos MenaSalesDaulejuan5@g mail . com note:fix-this   MenaSalesDaulejuan5@gmail.com                Juan Carlos            Juan Carlos     None   None                Juan Carlos
# 17  Javier MorenoQA LeadMachalajavier17@g mail . com note:fix-this   LeadMachalajavier17@gmail.com            Javier MorenoQA          Javier Moreno       QA   None            Javier MorenoQA
# 43                   Luis GomezSupport AgentTenaluis43@g mail . com      AgentTenaluis43@gmail.com          Luis GomezSupport             Luis Gomez  Support   None          Luis GomezSupport

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 500)

df_problem = df[df[["name", "role", "city"]].isna().any(axis=1)][
    ["Corrupted_Row", "clean_text", "name", "role", "city", "email"]
]
df_problem
# Out:
#                                                       Corrupted_Row                 clean_text                   name     role   city                          email
# 3                   \tMarioSánchez\tQALead\tManta\tmario3@gmail.com  MarioSánchez QALead Manta  Mario Sánchez QA Lead     None  Manta               mario3@gmail.com
# 5       Juan Carlos MenaSalesDaulejuan5@g mail . com note:fix-this                 Juan Carlos            Juan Carlos     None   None  MenaSalesDaulejuan5@gmail.com
# 17  Javier MorenoQA LeadMachalajavier17@g mail . com note:fix-this             Javier MorenoQA          Javier Moreno       QA   None  LeadMachalajavier17@gmail.com
# 43                   Luis GomezSupport AgentTenaluis43@g mail . com          Luis GomezSupport             Luis Gomez  Support   None      AgentTenaluis43@gmail.com

# %% [markdown]
# ## Exportación de archivo

# %%
df.to_csv("contacts_clean.csv", index=False, encoding="utf-8")

# %%
df.to_excel("contacts_clean.xlsx", index=False)
